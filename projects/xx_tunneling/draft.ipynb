# %%
import altair
import numpy
import pandas

# %%
def eckart_potential(nu_ts: float, e_forw: float, e_rev: float):
    a = e_forw - e_rev
    b = (numpy.sqrt(e_forw) + numpy.sqrt(e_rev)) ** 2

    def kappa(s: float) -> float:
        f = numpy.exp(s * numpy.abs(nu_ts) * numpy.sqrt(b / 2))
        return (f / (1 + f)) * (a + b / (1 + f))

    return kappa


s = numpy.linspace(-10, 10, 500)
kappa = eckart_potential(1/5, 50, 40)

source = pandas.DataFrame({"s": s, "kappa(s)": kappa(s)})

altair.Chart(source).mark_line().encode(x="s", y="kappa(s)")
# Out:
# alt.Chart(...)

# %%
from scipy.misc import derivative
import numpy as np

def f(x):
    return x**3 + 2*x**2 - 5*x + 1

x = np.array([1.0, 2.0, 3.0])

df_dx = derivative(kappa, 0, n=2, dx=1e-3)

print(df_dx)
# Expected Output: [ 2.000001  15.000001  34.000001]
# Out:
# -80.49917545349672
# /tmp/ipykernel_8636/3388710550.py:9: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   df_dx = derivative(kappa, 0, n=2, dx=1e-3)

# %%
import scipy
scipy.__version__
# Out:
# '1.12.0'
